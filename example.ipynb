# %%
from vine_seg.vine_seg import ViNeSeg
import matplotlib.pyplot as plt

model = ViNeSeg('models/vine_seg-allen.pt')

result = model.predict('data/allen/yolo/train/images/1120246770.png', conf=.5)

first_result = result[0] # result is a list because whole folders can be predicted

plt.imshow(first_result.plot())
# Out:
# image 1/1 /home/jonasm/work/vine-seg_segmentation/data/allen/yolo/train/images/1120246770.png: 640x640 54 cells, 17.4ms
# Speed: 1.5ms preprocess, 17.4ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
